# %%
import pandas as pd
pd.read_csv("ornekcsv.csv", sep=";") # csv dosyasını okuyoruz
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
pd.read_csv("duz_metin.txt") # csv dosyasını okuyoruz.
# Out:
#     1 2
# 0   2 2
# 1   3 2
# 2   4 2
# 3   5 2
# 4   6 2
# 5  7 2
# 6   8 2
# 7   9 2
# 8  10 2

# %%
df = pd.read_excel("ornekx.xlsx") # excel dosyasını okuyoruz
df.head() # ilk 5 satırı gösterir
# Out:
#     a    b    c
# 0  78   12  1.0
# 1  78   12  2.0
# 2  78  324  3.0
# 3   7    2  4.0
# 4  88   23  5.0

# %%
df.columns # sütunları gösterir
# Out:
# Index(['a', 'b', 'c'], dtype='object')
